# %% [markdown]
# Lab
# ==========================================
# Big Data I: StarCluster & IPython.parallel
# ------------------------------------------
# Alessandro D. Gagliardi

# %% [markdown]
# # Acquire Valued Shoppers Challenge
#
# <p><em>transactions<br></em><strong>id</strong>&nbsp;- A unique id representing a customer<br><strong>chain</strong> - An integer representing a store chain<br><strong>dept</strong>&nbsp;- An aggregate grouping of the Category (e.g. water)<br><strong>category</strong> - The product category (e.g. sparkling water)<br><strong>company</strong> - An id of the company&nbsp;that sells the item<br><strong>brand</strong> - An id of the brand to which the item belongs<br><strong>date</strong>&nbsp;- The date of purchase<br><strong>productsize</strong> - The amount of the product purchase (e.g. 16 oz of water)<br><strong>productmeasure</strong> - The units of the product purchase (e.g. ounces)<br><strong>purchasequantity</strong> - The number of units purchased<br><strong>purchaseamount</strong> - The dollar amount of the purchase</p>
#
# A negative value in productquantity and purchaseamount indicates a return.
#
# *see [kaggle.com/c/acquire-valued-shoppers-challenge](https://www.kaggle.com/c/acquire-valued-shoppers-challenge/data) for more details*

# %%
# %matplotlib inline
import os

import pandas as pd

from seaborn import plt
from boto.s3.connection import S3Connection
from IPython.parallel import Client

# %%
#note RH: b/c we have the AWS key in the bash profile we don't need this

#test - b/c we will need to push this into our starcluster cloud
credentials = pd.read_csv('/Users/rychughes/.ssh/credentials.csv')

# %%
#note RH: do not need the args b/c data in .ssh
#s3conn = S3Connection()
#transactions = s3conn.get_bucket('dat-sf-12')

#test - b/c we will need to push this into our starcluster cloud
s3conn = S3Connection(credentials['Access Key Id'][0], credentials['Secret Access Key'][0])
transactions = s3conn.get_bucket('dat-sf-12')

# %%
transaction_keys = transactions.get_all_keys(prefix='transactions')
len(transaction_keys)
# Out:
# 350

# %%
# %%time
# N.B. This takes a couple minutes...
transaction_keys[0].get_contents_to_filename('trans-aa.csv')
# Out:
# CPU times: user 1.21 s, sys: 1.27 s, total: 2.47 s
# Wall time: 29.3 s

# %%
pd.read_csv?

# %%
transactions_df = pd.read_csv('trans-aa.csv')

# %%
transactions_df
# Out:
#               id  chain  dept  category     company  brand        date  \
# 0          86246    205     7       707  1078778070  12564  2012-03-02
# 1          86246    205    63      6319   107654575  17876  2012-03-02
# 2          86246    205    97      9753  1022027929      0  2012-03-02
# 3          86246    205    25      2509   107996777  31373  2012-03-02
# 4          86246    205    55      5555   107684070  32094  2012-03-02
# 5          86246    205    97      9753  1021015020      0  2012-03-02
# 6          86246    205    99      9909   104538848  15343  2012-03-02
# 7          86246    205    59      5907   102900020   2012  2012-03-02
# 8          86246    205     9       921   101128414   9209  2012-03-02
# 9          86246    205    73      7344  1068142161  20285  2012-03-02
# 10         86246    205    41      4107   104113040  28204  2012-03-02
# 11         86246    205    21      2106   105100050  27873  2012-03-02
# 12         86246    205     8       814   102840020  18584  2012-03-02
# 13         86246    205    91      9122   108200080   2911  2012-03-02
# 14         86246    205    41      4120   101116616  15266  2012-03-02
# 15         86246    205    63      6315   107996777  31373  2012-03-02
# 16         86246    205     9       907   101410010  13791  2012-03-02
# 17         86246    205    97      9753  1021013323      0  2012-03-02
# 18         86246    205    45      4509  1082650484  59628  2012-03-02
# 19         86246    205    26      2630   103700030  14647  2012-03-02
# 20         86246    205     8       815   103900030  13296  2012-03-02
# 21         86246    205    81      8101   102820020  11186  2012-03-02
# 22         86246    205    56      5615   101116616  15266  2012-03-02
# 23         86246    205    58      5824   108674585  55172  2012-03-02
# 24         86246    205     9       907   107225070  12465  2012-03-02
# 25         86246    205    97      9753       10000      0  2012-03-02
# 26         86246    205     8       836   101116616  15266  2012-03-02
# 27         86246    205    19      1908   104530040  13915  2012-03-02
# 28         86246    205     9       904  1078735979   6734  2012-03-02
# 29         86246    205    64      6401   108066080   4098  2012-03-02
# ...          ...    ...   ...       ...         ...    ...         ...
# 999969  96847578     95    51      5124   107100777   5656  2013-04-22
# 999970  96847578     95    58      5835   108463282   8941  2013-04-24
# 999971  96847578     95    37      3709   107066272  12673  2013-04-25
# 999972  96847578     95    63      6315   102113020  10786  2013-04-25
# 999973  96847578     95    13      1306   102113020  15704  2013-04-25
# 999974  96847578     95    36      3601   101200010  13794  2013-04-26
# 999975  96847578     95    27      2705   105000050   6775  2013-04-27
# 999976  96847578     95    27      2705   105000050   6775  2013-05-01
# 999977  96847578     95    27      2705   105000050   6775  2013-05-03
# 999978  96847578     95    27      2705   105000050   6775  2013-05-06
# 999979  96847578     95    28      2805   102113020  15704  2013-05-08
# 999980  96847578     95    37      3703   105100050   2820  2013-05-08
# 999981  96847578     95    14      1416   102113020  15704  2013-05-08
# 999982  96847578     95    27      2705   105000050   6775  2013-05-08
# 999983  96847578     95    72      7205   103320030    305  2013-05-08
# 999984  96847578     95    27      2707   102113020  15704  2013-05-09
# 999985  96847578     95    99      9909   107127979   6732  2013-05-11
# 999986  96847578     95    27      2705   105000050   6775  2013-05-11
# 999987  96847578     95    27      2705   105000050   6775  2013-05-13
# 999988  96847578     95    58      5831   103927232  26234  2013-05-15
# 999989  96847578     95    27      2705   105000050   6775  2013-05-15
# 999990  96847578     95    27      2705   105000050   6775  2013-05-17
# 999991  96847578     95    36      3601   101200010  13794  2013-05-17
# 999992  96849591     88    64      6409   109998898  11499  2012-03-02
# 999993  96849591     88    26      2613   103600030   8583  2012-03-02
# 999994  96849591     88    56      5604   102113020  22356  2012-03-02
# 999995  96849591     88    64      6409   108751282  15423  2012-03-02
# 999996  96849591     88    79      7903  1072527474  27869  2012-03-02
# 999997  96849591     88    25      2506   102113020  10786  2012-03-08
# 999998  96849591     88    79      7903   107099272  27869  2012-03-08
#
#         productsize productmeasure  purchasequantity  purchaseamount
# 0             12.00             OZ                 1            7.59
# 1             64.00             OZ                 1            1.59
# 2              1.00             CT                 1            5.99
# 3             16.00             OZ                 1            1.99
# 4             16.00             OZ                 2           10.38
# 5              1.00             CT                 1            7.80
# 6             16.00             OZ                 1            2.49
# 7             16.00             OZ                 1            1.39
# 8              4.00             OZ                 2            1.50
# 9              8.00             CT                 1            5.79
# 10            14.50             OZ                 1            0.59
# 11            64.00             OZ                 1            3.29
# 12            15.50             OZ                 1            3.29
# 13            10.00             OZ                 1            1.99
# 14             6.00             OZ                 1            0.89
# 15            64.00             OZ                 1            3.59
# 16            24.00             OZ                 1            3.99
# 17             1.00             CT                 1            8.87
# 18            16.00             OZ                 1            4.99
# 19            56.00             CT                 1            1.00
# 20             8.00             OZ                 1            1.89
# 21             1.00             CT                 1            4.77
# 22            16.00             OZ                 1            6.29
# 23            16.00             OZ                 1            3.29
# 24            20.00             OZ                 1            2.99
# 25             1.00             CT                 1            0.69
# 26            64.00             OZ                 1            2.19
# 27            13.00             OZ                 1            3.69
# 28             5.00             OZ                 1            2.49
# 29           144.00             OZ                 1           14.69
# ...             ...            ...               ...             ...
# 999969        32.00             OZ                 2            6.38
# 999970        16.00             OZ                 2           10.98
# 999971        13.50             OZ                 2            3.73
# 999972        16.00             OZ                 1            0.95
# 999973         5.00             LB                 1            2.29
# 999974       288.00             OZ                 2            9.00
# 999975         5.50             OZ                 6            2.50
# 999976         5.50             OZ                 2            1.00
# 999977         5.50             OZ                 4            2.00
# 999978         5.50             OZ                 4            2.00
# 999979         3.80             OZ                 1            1.39
# 999980        10.75             OZ                 2            2.00
# 999981        15.25             OZ                 2            2.00
# 999982         5.50             OZ                 4            2.00
# 999983         6.00             OZ                 1            0.99
# 999984         7.00             LB                 1            6.99
# 999985        12.00             OZ                 1            0.99
# 999986         5.50             OZ                 4            2.00
# 999987         5.50             OZ                 2            1.00
# 999988        20.00             OZ                 4           25.96
# 999989         5.50             OZ                 2            1.00
# 999990         5.50             OZ                 5            2.00
# 999991       288.00             OZ                 2           10.00
# 999992         0.75             LT                 1            8.99
# 999993        23.00             CT                 1           10.49
# 999994         4.00             OZ                 1            3.99
# 999995         0.75             LT                 1            9.99
# 999996         1.00             CT                 1            4.99
# 999997        32.00             OZ                 1            2.49
# 999998         1.00             CT                 1            4.49
#
# [999999 rows x 11 columns]

# %%
transactions_df.head()
# Out:
#       id  chain  dept  category     company  brand        date  productsize  \
# 0  86246    205     7       707  1078778070  12564  2012-03-02           12
# 1  86246    205    63      6319   107654575  17876  2012-03-02           64
# 2  86246    205    97      9753  1022027929      0  2012-03-02            1
# 3  86246    205    25      2509   107996777  31373  2012-03-02           16
# 4  86246    205    55      5555   107684070  32094  2012-03-02           16
#
#   productmeasure  purchasequantity  purchaseamount
# 0             OZ                 1            7.59
# 1             OZ                 1            1.59
# 2             CT                 1            5.99
# 3             OZ                 1            1.99
# 4             OZ                 2           10.38

# %%
transactions_df.describe()
# Out:
#                     id         chain           dept       category  \
# count    999999.000000  999999.00000  999999.000000  999999.000000
# mean   63364052.944063      31.86412      41.416083    4155.292498
# std    24870195.303575      41.15973      27.773127    2779.941544
# min       86246.000000       2.00000       0.000000       0.000000
# 25%    54001770.000000      14.00000      18.000000    1850.000000
# 50%    68382868.000000      17.00000      36.000000    3628.000000
# 75%    82704044.000000      20.00000      60.000000    6001.000000
# max    96849591.000000     205.00000      99.000000    9999.000000
#
#             company          brand    productsize  purchasequantity  \
# count  9.999990e+05  999999.000000  999999.000000     999999.000000
# mean   2.180884e+08   16031.482528      28.686506          1.377621
# std    4.451214e+08   15418.426484      51.462686          1.086097
# min    1.000000e+04       0.000000       0.000000        -18.000000
# 25%    1.021130e+08    7755.000000       7.500000          1.000000
# 50%    1.039978e+08   13291.000000      14.500000          1.000000
# 75%    1.072891e+08   17090.000000      24.000000          1.000000
# max    1.099753e+10  108338.000000    4000.000000        124.000000
#
#        purchaseamount
# count   999999.000000
# mean         4.463513
# std          6.617972
# min       -163.490000
# 25%          2.190000
# 50%          3.490000
# 75%          5.290000
# max       1600.000000

# %%
transactions_df.groupby('id').purchasequantity.describe().head(24)
# Out:
# id
# 86246     count    12609.000000
#           mean         1.374653
#           std          1.018240
#           min          0.000000
#           25%          1.000000
#           50%          1.000000
#           75%          1.000000
#           max         22.000000
# 86252     count    12087.000000
#           mean         1.456441
#           std          1.224941
#           min         -1.000000
#           25%          1.000000
#           50%          1.000000
#           75%          2.000000
#           max         39.000000
# 12262064  count     1101.000000
#           mean         1.146231
#           std          0.511199
#           min          0.000000
#           25%          1.000000
#           50%          1.000000
#           75%          1.000000
#           max          8.000000
# dtype: float64

# %%
transactions_df.groupby('id').purchasequantity.describe().unstack().head(10)
# Out:
#           count      mean       std  min  25%  50%  75%  max
# id
# 86246     12609  1.374653  1.018240    0    1    1    1   22
# 86252     12087  1.456441  1.224941   -1    1    1    2   39
# 12262064   1101  1.146231  0.511199    0    1    1    1    8
# 12277270   1361  1.203527  0.605504    0    1    1    1    6
# 12332190    684  1.302632  1.059265    1    1    1    1   16
# 12524696    985  1.291371  0.850261   -3    1    1    1   10
# 12682470    806  1.217122  0.586604    1    1    1    1    7
# 12996040    326  1.233129  0.603279    1    1    1    1    5
# 13074629   1374  1.425764  1.482092   -1    1    1    1   36
# 13089312   1218  1.206076  0.485852    1    1    1    1    4

# %%
transactions_df.groupby('id').purchasequantity.count().hist()

# %%
transactions_df.groupby('id').purchasequantity.sum().hist()

# %%
transactions_df.groupby('id').purchasequantity.sum().hist(log='x')

# %%
transactions_df.groupby('id').purchaseamount.sum().hist(log='x')

# %%
transactions_df.groupby('date').purchaseamount.sum().plot()

# %% [markdown]
# ------------------------------------------
# Part 2
# ==========================================
# Moving to StarCluster
# ------------------------------------------

# %% [markdown]
# Add the `ipcluster` plugin if you haven't already.

# %% [markdown]
# Near the bottom of `.starcluster/config`:
# ```bash
# ######################
# ## Built-in Plugins ##
# ######################
# # The following plugins ship with StarCluster and should work out-of-the-box.
# # Uncomment as needed. Don't forget to update your PLUGINS list!
# # See http://star.mit.edu/cluster/docs/latest/plugins for plugin details.
# # .
# # .
# # .
# [plugin ipcluster]
# SETUP_CLASS = starcluster.plugins.ipcluster.IPCluster
# # Enable the IPython notebook server (optional)
# ENABLE_NOTEBOOK = True
# # Set a password for the notebook for increased security
# # This is optional but *highly* recommended
# NOTEBOOK_PASSWD = a-secret-password
# ```

# %% [markdown]
# Set `CLUSTER_SIZE` to `3` for more memory *(see [aws.amazon.com/ec2/instance-types](http://aws.amazon.com/ec2/instance-types/) for details)*:
# ```bash
# [cluster smallcluster]
# # number of ec2 instances to launch
# CLUSTER_SIZE = 3
# NODE_IMAGE_ID = ami-6b211202
# PLUGINS = ipcluster
# SPOT_BID = 0.10
# ```
# Also set `SPOT_BID` to `0.10` (or less?) to save $$$ *(see [aws.amazon.com/ec2/purchasing-options/spot-instances](http://aws.amazon.com/ec2/purchasing-options/spot-instances/) for details)*

# %% [markdown]
# Start your new cluster:

# %% [markdown]
# `$ starcluster start my_cluster`

# %% [markdown]
# Copy your credentials to your cluster:

# %% [markdown]
# `$ starcluster put my_cluster --user sgeadmin ~/Downloads/credentials.csv /home/sgeadmin/`

# %% [markdown]
# This should, as a side effect, add your cluster to the list of known hosts on your machine.
# In my experience, it often doesn't, however.
# Therefore, **you will want to:**
#
# ```bash
# starcluster sshmaster my_cluster
# ```
# **before you do the following (or `Client` will hang forever):**

# %%
#small cluster
#url_file = os.path.expanduser('~/.starcluster/ipcluster/SecurityGroup:@sc-smallcluster-us-east-1.json')
#med cluster
url_file = os.path.expanduser('~/.starcluster/ipcluster/SecurityGroup:@sc-mediumcluster-us-east-1.json')

sshkey = os.path.expanduser('~/.ssh/aws_key_crh.rsa')  
client = Client(url_file, sshkey = sshkey)

# %% [markdown]
# Check to see how many engines you have running:

# %%
dview = client.direct_view()
len(client.ids)
# Out:
# 3

# %% [markdown]
# If there are fewer engines running than expected, that's probably because they didn't start on some of the instances. We can use the following to see which instances have engines:

# %%
# %%px
# %%bash
# ec2metadata --local-ipv4
# Out:
# [stdout:0] 172.31.55.83
# [stdout:1] 172.31.55.84
# [stdout:2] 172.31.55.82

# %% [markdown]
# We need to set up each of our engines individually. We can do this quickly with the `%%px` magic:

# %%
# %%px
# import pandas as pd
# from boto.s3.connection import S3Connection
# from collections import defaultdict
#
# credentials = pd.read_csv('credentials.csv')
#
# s3conn = S3Connection(credentials['Access Key Id'][0], credentials['Secret Access Key'][0])
# transactions = s3conn.get_bucket('dat-sf-12')

# %% [markdown]
# We then scatter the keys to our S3 files across our cluster:

# %%
dview.scatter('transaction_keys', [key.name for key in transaction_keys], dist='r')
# Out:
# <AsyncResult: scatter>

# %% [markdown]
# Since all but the first file are missing a header, we will want to use the column names from the first file and push that to our engines:

# %%
dview.push({'transaction_columns': list(transactions_df.columns)})
# Out:
# <AsyncResult: _push>

# %%
# %%px -t 0
# transaction_columns
# Out:
# Out[0:3]:
# ['id',
#  'chain',
#  'dept',
#  'category',
#  'company',
#  'brand',
#  'date',
#  'productsize',
#  'productmeasure',
#  'purchasequantity',
#  'purchaseamount']

# %% [markdown]
# If we were unable to investigate our data locally (perhaps the download failed) we can do so on engine zero by specifying the `target` thus:
# *(only do this if the above attempt at running `get_contents_as_string` failed)*

# %%
# %%px
# len(transaction_keys)
# Out:
# Out[0:4]: 117
# Out[1:3]: 117
# Out[2:3]: 116

# %%
# %%px --targets 0
# twokeys = transaction_keys[:2]
# twokeys
# Out:
# Out[0:5]: [u'transactions/trans-aa', u'transactions/trans-ad']

# %%
# %%px -t0
# transactions_df = pd.DataFrame(columns=transaction_columns)
# for key_name in twokeys:
#     filename = '/mnt/sgeadmin/{}.csv'.format(key_name.split('/')[-1])
#     transaction_key = transactions.get_key(key_name)
#     transaction_key.get_contents_to_filename(filename)
#     if 'trans-aa' in filename:
#         skiprows = 1
#     else:
#         skiprows = 0
#     transactions_df = transactions_df.append(pd.read_csv(filename, names = transaction_columns, skiprows = skiprows))

# %% [markdown]
# Why `/mnt/sgeadmin/`? EC2 instances don't put very much storage capacity in the `/home/` directory. Instead, the large storage volume is mounted at `/mnt/`. `/mnt/` is owned by `root` so IPython can't write there (since IPython is run by `sgeadmin`) but `/mnt/sgeadmin/` is owned by `sgeadmin` and so that is where we will write our files.

# %%
# %%px -t0
# #note does not run on -t1
# transactions_df.shape
# Out:
# Out[0:8]: (1999999, 11)

# %%
# %%px
# #note -tX is not defined
# transactions_df = pd.DataFrame(columns=transaction_columns)
# for key_name in transaction_keys:
#     filename = '/mnt/sgeadmin/{}.csv'.format(key_name.split('/')[-1])
#     transaction_key = transactions.get_key(key_name)
#     transaction_key.get_contents_to_filename(filename)
#     if 'trans-aa' in filename:
#         skiprows = 1
#     else:
#         skiprows = 0
#     transactions_df = transactions_df.append(pd.read_csv(filename, names = transaction_columns, skiprows = skiprows))
# Out:
# [0:execute]:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)<ipython-input-9-292a20253650> in <module>()
#       9     else:
#      10         skiprows = 0
# ---> 11     transactions_df = transactions_df.append(pd.read_csv(filename, names = transaction_columns, skiprows = skiprows))
# /usr/local/lib/python2.7/dist-packages/pandas/core/frame.pyc in append(self, other, ignore_index, verify_integrity)
#    4606             to_concat = [self, other]
#    4607         return concat(to_concat, ignore_index=ignore_index,
# -> 4608                       verify_integrity=verify_integrity)
#    4609
#    4610     def join(self, other, on=None, how='left', lsuffix='', rsuffix='',
# /usr/local/lib/python2.7/dist-packages/pandas/tools/merge.pyc in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity)
#     877                        keys=keys, levels=levels, names=names,
#     878                        verify_integrity=verify_integrity)
# --> 879     return op.get_result()
#     880
#     881
# /usr/local/lib/python2.7/dist-packages/pandas/tools/merge.pyc in get_result(self)
#     967             return tmpdf
#     968         else:
# --> 969             new_data = self._get_concatenated_data()
#     970             return self.objs[0]._from_axes(new_data, self.new_axes)
#     971
# /usr/local/lib/python2.7/dist-packages/pandas/tools/merge.pyc in _get_concatenated_data(self)
#    1012             new_data = {}
#    1013             for item in self.new_axes[0]:
# -> 1014                 new_data[item] = self._concat_single_item(rdata, item)
#    1015
#    1016         return new_data
# /usr/local/lib/python2.7/dist-packages/pandas/tools/merge.pyc in _concat_single_item(self, objs, item)
#    1113         if not ((self.axis >= 1)):
#    1114             raise AssertionError()
# -> 1115         return com._concat_compat(to_concat, axis=self.axis - 1)
#    1116
#    1117     def _get_result_dim(self):
# /usr/local/lib/python2.7/dist-packages/pandas/core/common.pyc in _concat_compat(to_concat, axis)
#    1829         to_concat = [_to_pydatetime(x) for x in to_concat]
#    1830
# -> 1831     return np.concatenate(to_concat, axis=axis)
#    1832
#    1833
# MemoryError:
#
# [1:execute]:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)<ipython-input-4-292a20253650> in <module>()
#       9     else:
#      10         skiprows = 0
# ---> 11     transactions_df = transactions_df.append(pd.read_csv(filename, names = transaction_columns, skiprows = skiprows))
# /usr/local/lib/python2.7/dist-packages/pandas/core/frame.pyc in append(self, other, ignore_index, verify_integrity)
#    4606             to_concat = [self, other]
#    4607         return concat(to_concat, ignore_index=ignore_index,
# -> 4608                       verify_integrity=verify_integrity)
#    4609
#    4610     def join(self, other, on=None, how='left', lsuffix='', rsuffix='',
# /usr/local/lib/python2.7/dist-packages/pandas/tools/merge.pyc in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity)
#     877                        keys=keys, levels=levels, names=names,
#     878                        verify_integrity=verify_integrity)
# --> 879     return op.get_result()
#     880
#     881
# /usr/local/lib/python2.7/dist-packages/pandas/tools/merge.pyc in get_result(self)
#     967             return tmpdf
#     968         else:
# --> 969             new_data = self._get_concatenated_data()
#     970             return self.objs[0]._from_axes(new_data, self.new_axes)
#     971
# /usr/local/lib/python2.7/dist-packages/pandas/tools/merge.pyc in _get_concatenated_data(self)
#    1012             new_data = {}
#    1013             for item in self.new_axes[0]:
# -> 1014                 new_data[item] = self._concat_single_item(rdata, item)
#    1015
#    1016         return new_data
# /usr/local/lib/python2.7/dist-packages/pandas/tools/merge.pyc in _concat_single_item(self, objs, item)
#    1113         if not ((self.axis >= 1)):
#    1114             raise AssertionError()
# -> 1115         return com._concat_compat(to_concat, axis=self.axis - 1)
#    1116
#    1117     def _get_result_dim(self):
# /usr/local/lib/python2.7/dist-packages/pandas/core/common.pyc in _concat_compat(to_concat, axis)
#    1829         to_concat = [_to_pydatetime(x) for x in to_concat]
#    1830
# -> 1831     return np.concatenate(to_concat, axis=axis)
#    1832
#    1833
# MemoryError:
#
# [2:execute]:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)<ipython-input-4-292a20253650> in <module>()
#       9     else:
#      10         skiprows = 0
# ---> 11     transactions_df = transactions_df.append(pd.read_csv(filename, names = transaction_columns, skiprows = skiprows))
# /usr/local/lib/python2.7/dist-packages/pandas/core/frame.pyc in append(self, other, ignore_index, verify_integrity)
#    4606             to_concat = [self, other]
#    4607         return concat(to_concat, ignore_index=ignore_index,
# -> 4608                       verify_integrity=verify_integrity)
#    4609
#    4610     def join(self, other, on=None, how='left', lsuffix='', rsuffix='',
# /usr/local/lib/python2.7/dist-packages/pandas/tools/merge.pyc in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity)
#     877                        keys=keys, levels=levels, names=names,
#     878                        verify_integrity=verify_integrity)
# --> 879     return op.get_result()
#     880
#     881
# /usr/local/lib/python2.7/dist-packages/pandas/tools/merge.pyc in get_result(self)
#     967             return tmpdf
#     968         else:
# --> 969             new_data = self._get_concatenated_data()
#     970             return self.objs[0]._from_axes(new_data, self.new_axes)
#     971
# /usr/local/lib/python2.7/dist-packages/pandas/tools/merge.pyc in _get_concatenated_data(self)
#    1012             new_data = {}
#    1013             for item in self.new_axes[0]:
# -> 1014                 new_data[item] = self._concat_single_item(rdata, item)
#    1015
#    1016         return new_data
# /usr/local/lib/python2.7/dist-packages/pandas/tools/merge.pyc in _concat_single_item(self, objs, item)
#    1113         if not ((self.axis >= 1)):
#    1114             raise AssertionError()
# -> 1115         return com._concat_compat(to_concat, axis=self.axis - 1)
#    1116
#    1117     def _get_result_dim(self):
# /usr/local/lib/python2.7/dist-packages/pandas/core/common.pyc in _concat_compat(to_concat, axis)
#    1829         to_concat = [_to_pydatetime(x) for x in to_concat]
#    1830
# -> 1831     return np.concatenate(to_concat, axis=axis)
#    1832
#    1833
# MemoryError:

# %% [markdown]
# ------------------------------------------
# Intermission
# ------------------------------------------
# ------------------------------------------
# While you're waiting...
# ```bash
# starcluster sshmaster my_medium_cluster
# htop
# ```
# ------------------------------------------

# %%
# %%px
# user_id_counts = transactions_df.groupby('id').purchasequantity.count()

# %%
# %%px -t 0:10:3
# len(user_id_counts)
# Out:
# Out[0:21]: 6271
# Out[3:12]: 7746
# Out[6:11]: 7028
# Out[9:11]: 7458

# %%
# %%px
# user_id_counts_dict = user_id_counts.to_dict()

# %%
#note this is now on local machine
user_id_counts_list = dview.gather('user_id_counts_dict').get()

# %%
user_id_counts_series = pd.DataFrame(map(pd.Series, user_id_counts_list)).sum()

# %%
user_id_counts_series.hist(log='x')

# %% [markdown]
# Lab
# ---------
# In pairs:
# =========
# Plot the sum of the purchase amount by date using all of the data

# %% [markdown]
# ### If you think that was easy:
# Get offers and history files from [kaggle.com/c/acquire-valued-shoppers-challenge/data](https://www.kaggle.com/c/acquire-valued-shoppers-challenge/data)/. The transactions file can be joined to the history file by (id,chain). The history file can be joined to the offers file by (offer). The transactions file can be joined to the offers file by (category, brand, company).
#
# *Hint: the easiest way to do this is probably to copy those tables to every engine.*
#
# Using outer joins, what can you discover about these data?

# %% [markdown]
# ------------------------------------------
# # ¡¡¡DON'T FORGET TO TERMINATE YOUR CLUSTER BEFORE YOU LEAVE CLASS!!!
# ------------------------------------------
